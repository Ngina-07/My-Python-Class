# %% [markdown]
# # Introduction to python

# %%
print("Where is the place called Bombblast in Nairobi?")
# Out:
# Where is the place called Bombblast in Nairobi?

# %% [markdown]
# ## Variables in python

# %%
total_price =10+20
total_price
# Out:
# 30

# %%
type(total_price)
# Out:
# int

# %%
# A string variable
fav_fruit ="Grapes"

# %%
Travelledbytrain=True
type(Travelledbytrain)
# Out:
# bool

# %%
# this is a string
fav_colour='purple'

# %%
#thi is a string
name="my sister's name is Rita"

# %% [markdown]
# # Naming conventions for variables in python
# **snake case**
# total_spend =20
#
# **camel case**
# totalspend =20
#
# **pascal case**
# totalspend =20

# %% [markdown]
# ### calculations with variables

# %%
original_price = 7000
price_after_discount= 6760
# what is the discount in percentage?
discount = original_price- price_after_discount
percentage = (discount/original_price)*100
print(percentage)
# Out:
# 3.428571428571429
